# %%
import json

# %%
all_filesets = {
    "VBF_SMEFTsim_topU3l_NP1": [
        "/eos/uscms/store/user/jdickins/vbf-eft/el8/VBF_SMEFTsim_topU3l_NP1/VBF_SMEFTsim_topU3l_NP1/241211_173139/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_NP1_start1": [
        "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_NP1_start1/VBF_SMEFTsim_topU3l_NP1_start1/241212_152743/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],   
    "VBF_SMEFTsim_topU3l_cHbox": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cHbox/VBF_SMEFTsim_topU3l_cHbox/241211_200840/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cHj1": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cHj1/VBF_SMEFTsim_topU3l_cHj1/241211_201633/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cHj3": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cHj3/VBF_SMEFTsim_topU3l_cHj3/241211_202332/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cHW": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cHW/VBF_SMEFTsim_topU3l_cHW/241211_200126/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cHWtil": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cHWtil/VBF_SMEFTsim_topU3l_cHWtil/241211_200605/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cdBIm": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cdBIm/VBF_SMEFTsim_topU3l_cdBIm/241211_183348/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cdBRe": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cdBRe/VBF_SMEFTsim_topU3l_cdBRe/241211_203147/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cdWIm": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cdWIm/VBF_SMEFTsim_topU3l_cdWIm/241211_203627/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cdWRe": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cdWRe/VBF_SMEFTsim_topU3l_cdWRe/241211_203939/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cHB": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cHB/VBF_SMEFTsim_topU3l_cHB/241211_184743/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cHBtil": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cHBtil/VBF_SMEFTsim_topU3l_cHBtil/241211_184859/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cHd": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cHd/VBF_SMEFTsim_topU3l_cHd/241211_201320/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cHDD": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cHDD/VBF_SMEFTsim_topU3l_cHDD/241211_185352/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cHu": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cHu/VBF_SMEFTsim_topU3l_cHu/241211_202401/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cHudRe": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cHudRe/VBF_SMEFTsim_topU3l_cHudRe/241211_203126/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cHudIm": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cHudIm/VBF_SMEFTsim_topU3l_cHudIm/241211_203055/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cHWB": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cHWB/VBF_SMEFTsim_topU3l_cHWB/241211_185745/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cHWBtil": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cHWBtil/VBF_SMEFTsim_topU3l_cHWBtil/241211_195759/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cuBIm": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cuBIm/VBF_SMEFTsim_topU3l_cuBIm/241211_204841/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cuBRe": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cuBRe/VBF_SMEFTsim_topU3l_cuBRe/241211_213801/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cuWIm": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cuWIm/VBF_SMEFTsim_topU3l_cuWIm/241211_214616/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
    "VBF_SMEFTsim_topU3l_cuWRe": [
         "/eos/uscms/store/user/jennetd/vbf-eft/el8/VBF_SMEFTsim_topU3l_cuWRe/VBF_SMEFTsim_topU3l_cuWRe/241211_214847/0000/nanogen_123_"+str(i)+".root" for i in range(1,201)
    ],
}

# %%
# Make jsons for all the samples. Easy!
for k in all_filesets.keys():
    print(k)
    for_json = {}
    for_json["files"] = all_filesets[k]
    #for_json["year"] = "2023" #FIXME
    for_json["xsec"] = 1 #FIXME
    for_json["nSumOfWeights"] = 72473.836
    for_json["histAxisName"] = k
    for_json["treeName"] = "Events"

    with open('jsons/' + k + '.json', 'w') as f:
        json.dump(for_json, f)
# Out:
# VBF_SMEFTsim_topU3l_NP1
# VBF_SMEFTsim_topU3l_NP1_start1
# VBF_SMEFTsim_topU3l_cHbox
# VBF_SMEFTsim_topU3l_cHj1
# VBF_SMEFTsim_topU3l_cHj3
# VBF_SMEFTsim_topU3l_cHW
# VBF_SMEFTsim_topU3l_cHWtil
# VBF_SMEFTsim_topU3l_cdBIm
# VBF_SMEFTsim_topU3l_cdBRe
# VBF_SMEFTsim_topU3l_cdWIm
# VBF_SMEFTsim_topU3l_cdWRe
# VBF_SMEFTsim_topU3l_cHB
# VBF_SMEFTsim_topU3l_cHBtil
# VBF_SMEFTsim_topU3l_cHd
# VBF_SMEFTsim_topU3l_cHDD
# VBF_SMEFTsim_topU3l_cHu
# VBF_SMEFTsim_topU3l_cHudRe
# VBF_SMEFTsim_topU3l_cHudIm
# VBF_SMEFTsim_topU3l_cHWB
# VBF_SMEFTsim_topU3l_cHWBtil
# VBF_SMEFTsim_topU3l_cuBIm
# VBF_SMEFTsim_topU3l_cuBRe
# VBF_SMEFTsim_topU3l_cuWIm
# VBF_SMEFTsim_topU3l_cuWRe
